# %% [markdown]
# # Extract Content from Your File

# %% [markdown]
# This notebook demonstrate you can use Content Understanding API to extract semantic content from multimodal files.

# %% [markdown]
# ## Prerequisites
# 1. Ensure Azure AI service is configured following [steps](../README.md#configure-azure-ai-service-resource)
# 2. Install the required packages to run the sample.

# %%
# %pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: azure-identity in c:\users\jomedin\appdata\local\anaconda3\envs\secdemo\lib\site-packages (from -r ../requirements.txt (line 1)) (1.19.0)
# Requirement already satisfied: python-dotenv in c:\users\jomedin\appdata\local\anaconda3\envs\secdemo\lib\site-packages (from -r ../requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: requests in c:\users\jomedin\appdata\local\anaconda3\envs\secdemo\lib\site-packages (from -r ../requirements.txt (line 3)) (2.32.3)
# Requirement already satisfied: Pillow in c:\users\jomedin\appdata\local\anaconda3\envs\secdemo\lib\site-packages (from -r ../requirements.txt (line 4)) (10.3.0)
# Requirement already satisfied: azure-core>=1.31.0 in c:\users\jomedin\appdata\local\anaconda3\envs\secdemo\lib\site-packages (from azure-identity->-r ../requirements.txt (line 1)) (1.32.0)
# Requirement already satisfied: cryptography>=2.5 in c:\users\jomedin\appdata\local\anaconda3\envs\secdemo\lib\site-packages (from azure-identity->-r ../requirements.txt (line 1)) (42.0.5)
# Requirement already satisfied: msal>=1.30.0 in c:\users\jomedin\appdata\local\anaconda3\envs\secdemo\lib\site-packages (from azure-identity->-r ../requirements.txt (line 1)) (1.31.1)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\jomedin\appdata\local\anaconda3\envs\secdemo\lib\site-packages (from azure-identity->-r ../requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\jomedin\appdata\local\anaconda3\envs\secdemo\lib\site-packages (from azure-identity->-r ../requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jomedin\appdata\local\anaconda3\envs\secdemo\lib\site-packages (from requests->-r ../requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jomedin\appdata\local\anaconda3\envs\secdemo\lib\site-packages (from requests->-r ../requirements.txt (line 3)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jomedin\appdata\local\anaconda3\envs\secdemo\lib\site-packages (from requests->-r ../requirements.txt (line 3)) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jomedin\appdata\local\anaconda3\envs\secdemo\lib\site-packages (from requests->-r ../requirements.txt (line 3)) (2024.12.14)
# Requirement already satisfied: six>=1.11.0 in c:\users\jomedin\appdata\local\anaconda3\envs\secdemo\lib\site-packages (from azure-core>=1.31.0->azure-identity->-r ../requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\jomedin\appdata\local\anaconda3\envs\secdemo\lib\site-packages (from cryptography>=2.5->azure-identity->-r ../requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\jomedin\appdata\local\anaconda3\envs\secdemo\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity->-r ../requirements.txt (line 1)) (2.8.0)
# Requirement already satisfied: portalocker<3,>=1.4 in c:\users\jomedin\appdata\local\anaconda3\envs\secdemo\lib\site-packages (from msal-extensions>=1.2.0->azure-identity->-r ../requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pycparser in c:\users\jomedin\appdata\local\anaconda3\envs\secdemo\lib\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity->-r ../requirements.txt (line 1)) (2.22)
# Requirement already satisfied: pywin32>=226 in c:\users\jomedin\appdata\local\anaconda3\envs\secdemo\lib\site-packages (from portalocker<3,>=1.4->msal-extensions>=1.2.0->azure-identity->-r ../requirements.txt (line 1)) (305.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Create Azure AI Content Understanding Client
#
# > The [AzureContentUnderstandingClient](../python/content_understanding_client.py) is a utility class containing functions to interact with the Content Understanding API. Before the official release of the Content Understanding SDK, it can be regarded as a lightweight SDK.

# %%
import logging
import json
import os
import sys
import uuid
from pathlib import Path
from dotenv import find_dotenv, load_dotenv
from azure.identity import DefaultAzureCredential, get_bearer_token_provider

load_dotenv(find_dotenv())
logging.basicConfig(level=logging.INFO)

AZURE_AI_ENDPOINT = os.getenv("AZURE_AI_ENDPOINT")
AZURE_AI_API_VERSION = os.getenv("AZURE_AI_API_VERSION", "2024-12-01-preview")

# Add the parent directory to the path to use shared modules
parent_dir = Path(Path.cwd()).parent
sys.path.append(str(parent_dir))
from python.content_understanding_client import AzureContentUnderstandingClient

credential = DefaultAzureCredential()
token_provider = get_bearer_token_provider(credential, "https://cognitiveservices.azure.com/.default")

client = AzureContentUnderstandingClient(
    endpoint=AZURE_AI_ENDPOINT,
    api_version=AZURE_AI_API_VERSION,
    token_provider=token_provider,
    x_ms_useragent="azure-ai-content-understanding-python/content_extraction", # This header is used for sample usage telemetry, please comment out this line if you want to opt out.
)

# Utility function to save images
from PIL import Image
from io import BytesIO
import re

def save_image(image_id: str, response):
    raw_image = client.get_image_from_analyze_operation(analyze_response=response,
        image_id=image_id
    )
    image = Image.open(BytesIO(raw_image))
    # image.show()
    Path(".cache").mkdir(exist_ok=True)
    image.save(f".cache/{image_id}.jpg", "JPEG")
# Out:
# INFO:azure.identity._credentials.environment:No environment configuration found.
# INFO:azure.identity._credentials.managed_identity:ManagedIdentityCredential will use IMDS
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.19.0 Python/3.12.2 (Windows-11-10.0.26100-SP0)'
# No body was attached to the request
# INFO:azure.identity._credentials.chained:DefaultAzureCredential acquired a token from AzureCliCredential

# %% [markdown]
# ## Document Content
#
# Content Understanding API is designed to extract all textual content from a specified document file. In addition to text extraction, it conducts a comprehensive layout analysis to identify and categorize tables and figures within the document. The output is then presented in a structured markdown format, ensuring clarity and ease of interpretation.

# %%
ANALYZER_ID = "content-doc-sample-" + str(uuid.uuid4())
ANALYZER_TEMPLATE_FILE = '../analyzer_templates/content_document.json'
ANALYZER_SAMPLE_FILE = '../data/invoice.pdf'

# Create analyzer
response = client.begin_create_analyzer(ANALYZER_ID, analyzer_template_path=ANALYZER_TEMPLATE_FILE)
result = client.poll_result(response)

# Analyzer file
response = client.begin_analyze(ANALYZER_ID, file_location=ANALYZER_SAMPLE_FILE)
result = client.poll_result(response)

print(json.dumps(result, indent=2))
client.delete_analyzer(ANALYZER_ID)
# Out:
# INFO:python.content_understanding_client:Analyzer content-doc-sample-0fc2efd5-0f05-4ab1-a2ea-f6751c38c57c create request accepted.
# INFO:python.content_understanding_client:Request result is ready after 0.00 seconds.
# INFO:python.content_understanding_client:Analyzing file ../data/invoice.pdf with analyzer: content-doc-sample-0fc2efd5-0f05-4ab1-a2ea-f6751c38c57c
# INFO:python.content_understanding_client:Request 067c0a2a-491d-4dc5-bb48-8a001368625a in progress ...
# INFO:python.content_understanding_client:Request 067c0a2a-491d-4dc5-bb48-8a001368625a in progress ...
# INFO:python.content_understanding_client:Request result is ready after 5.02 seconds.
# {
#   "id": "067c0a2a-491d-4dc5-bb48-8a001368625a",
#   "status": "Succeeded",
#   "result": {
#     "analyzerId": "content-doc-sample-0fc2efd5-0f05-4ab1-a2ea-f6751c38c57c",
#     "apiVersion": "2024-12-01-preview",
#     "createdAt": "2025-03-06T16:48:58Z",
#     "warnings": [],
#     "contents": [
#       {
#         "markdown": "CONTOSO LTD.\n\n\n# INVOICE\n\nContoso Headquarters\n123 456th St\nNew York, NY, 10001\n\nINVOICE: INV-100\n\nINVOICE DATE: 11/15/2019\n\nDUE DATE: 12/15/2019\n\nCUSTOMER NAME: MICROSOFT CORPORATION\n\nSERVICE PERIOD: 10/14/2019 - 11/14/2019\n\nCUSTOMER ID: CID-12345\n\nMicrosoft Corp\n123 Other St,\nRedmond WA, 98052\n\nBILL TO:\n\nMicrosoft Finance\n\n123 Bill St,\n\nRedmond WA, 98052\n\nSHIP TO:\n\nMicrosoft Delivery\n\n123 Ship St,\n\nRedmond WA, 98052\n\nSERVICE ADDRESS:\nMicrosoft Services\n123 Service St,\nRedmond WA, 98052\n\n\n<table>\n<tr>\n<th>SALESPERSON</th>\n<th>P.O. NUMBER</th>\n<th>REQUISITIONER</th>\n<th>SHIPPED VIA</th>\n<th>F.O.B. POINT</th>\n<th>TERMS</th>\n</tr>\n<tr>\n<td></td>\n<td>PO-3333</td>\n<td></td>\n<td></td>\n<td></td>\n<td></td>\n</tr>\n</table>\n\n\n<table>\n<tr>\n<th>DATE</th>\n<th>ITEM CODE</th>\n<th>DESCRIPTION</th>\n<th>QTY</th>\n<th>UM</th>\n<th>PRICE</th>\n<th>TAX</th>\n<th>AMOUNT</th>\n</tr>\n<tr>\n<td>3/4/2021</td>\n<td>A123</td>\n<td>Consulting Services</td>\n<td>2</td>\n<td>hours</td>\n<td>$30.00</td>\n<td>$6.00</td>\n<td>$60.00</td>\n</tr>\n<tr>\n<td>3/5/2021</td>\n<td>B456</td>\n<td>Document Fee</td>\n<td>3</td>\n<td></td>\n<td>$10.00</td>\n<td>$3.00</td>\n<td>$30.00</td>\n</tr>\n<tr>\n<td>3/6/2021</td>\n<td>C789</td>\n<td>Printing Fee</td>\n<td>10</td>\n<td>pages</td>\n<td>$1.00</td>\n<td>$1.00</td>\n<td>$10.00</td>\n</tr>\n</table>\n\n\n<table>\n<tr>\n<td>SUBTOTAL</td>\n<td>$100.00</td>\n</tr>\n<tr>\n<td>SALES TAX</td>\n<td>$10.00</td>\n</tr>\n<tr>\n<td>TOTAL</td>\n<td>$110.00</td>\n</tr>\n<tr>\n<td>PREVIOUS UNPAID BALANCE</td>\n<td>$500.00</td>\n</tr>\n<tr>\n<td>AMOUNT DUE</td>\n<td>$610.00</td>\n</tr>\n</table>\n\n\nTHANK YOU FOR YOUR BUSINESS!\n\nREMIT TO:\n\nContoso Billing\n\n123 Remit St\n\nNew York, NY, 10001\n",
#         "kind": "document",
#         "startPageNumber": 1,
#         "endPageNumber": 1,
#         "unit": "inch",
#         "pages": [
#           {
#             "pageNumber": 1,
#             "angle": -0.0039,
#             "width": 8.5,
#             "height": 11
#           }
#         ]
#       }
#     ]
#   }
# }
# INFO:python.content_understanding_client:Analyzer content-doc-sample-0fc2efd5-0f05-4ab1-a2ea-f6751c38c57c deleted.
# <Response [204]>

# %% [markdown]
# ## Audio Content
# Our API output facilitates detailed analysis of spoken language, allowing developers to utilize the data for various applications, such as voice recognition, customer service analytics, and conversational AI. The structure of the output makes it easy to extract and analyze different components of the conversation for further processing or insights.
#
# 1. Speaker Identification: Each phrase is attributed to a specific speaker (in this case, "Speaker 2"). This allows for clarity in conversations with multiple participants.
# 1. Timing Information: Each transcription includes precise timing data:
#     - startTimeMs: The time (in milliseconds) when the phrase begins.
#     - endTimeMs: The time (in milliseconds) when the phrase ends.
#     This information is crucial for applications like video subtitles, allowing synchronization between the audio and the text.
# 1. Text Content: The actual spoken text is provided, which in this instance is "Thank you for calling Woodgrove Travel." This is the main content of the transcription.
# 1. Confidence Score: Each transcription phrase includes a confidence score (0.933 in this case), indicating the likelihood that the transcription is accurate. A higher score suggests greater reliability.
# 1. Word-Level Breakdown: The transcription is further broken down into individual words, each with its own timing information. This allows for detailed analysis of speech patterns and can be useful for applications such as language processing or speech recognition improvement.
# 1. Locale Specification: The locale is specified as "en-US," indicating that the transcription is in American English. This is important for ensuring that the transcription algorithms account for regional dialects and pronunciations.

# %%
ANALYZER_ID = "content-audio-sample-" + str(uuid.uuid4())
ANALYZER_TEMPLATE_FILE = '../analyzer_templates/audio_transcription.json'
ANALYZER_SAMPLE_FILE = '../data/audio.wav'

# Create analyzer
response = client.begin_create_analyzer(ANALYZER_ID, analyzer_template_path=ANALYZER_TEMPLATE_FILE)
result = client.poll_result(response)

# Analyzer file
response = client.begin_analyze(ANALYZER_ID, file_location=ANALYZER_SAMPLE_FILE)
result = client.poll_result(response)

print(json.dumps(result, indent=2))
client.delete_analyzer(ANALYZER_ID)
# Out:
# INFO:python.content_understanding_client:Analyzer content-audio-sample-5a7f609f-dee6-49ac-9632-61a0c1ed18f5 create request accepted.
# INFO:python.content_understanding_client:Request result is ready after 0.00 seconds.
# INFO:python.content_understanding_client:Analyzing file ../data/audio.wav with analyzer: content-audio-sample-5a7f609f-dee6-49ac-9632-61a0c1ed18f5
# INFO:python.content_understanding_client:Request 6464bc8d-b9ca-499f-bfcd-682a405929be in progress ...
# INFO:python.content_understanding_client:Request 6464bc8d-b9ca-499f-bfcd-682a405929be in progress ...
# INFO:python.content_understanding_client:Request 6464bc8d-b9ca-499f-bfcd-682a405929be in progress ...
# INFO:python.content_understanding_client:Request result is ready after 7.45 seconds.
# {
#   "id": "6464bc8d-b9ca-499f-bfcd-682a405929be",
#   "status": "Succeeded",
#   "result": {
#     "analyzerId": "content-audio-sample-5a7f609f-dee6-49ac-9632-61a0c1ed18f5",
#     "apiVersion": "2024-12-01-preview",
#     "createdAt": "2025-03-06T16:49:08Z",
#     "warnings": [],
#     "contents": [
#       {
#         "markdown": "```WEBVTT\n\n00:00.080 --> 00:02.160\n<v Speaker 1>Thank you for calling Woodgrove Travel.\n\n00:02.960 --> 00:04.560\n<v Speaker 1>My name is Isabella Taylor.\n\n00:05.360 --> 00:06.880\n<v Speaker 1>How may I assist you today?\n\n00:07.680 --> 00:10.240\n<v Speaker 2>Hi Isabella, my name is John Smith.\n\n00:11.120 --> 00:17.920\n<v Speaker 2>I recently traveled from New York City to Los Angeles on a business trip, and I had a terrible experience with my flight.\n\n00:18.720 --> 00:20.880\n<v Speaker 1>I'm sorry to hear that, John.\n\n00:21.680 --> 00:27.200\n<v Speaker 1>Could you please provide me with the details of your flight, such as the airline name and flight number?\n\n00:28.000 --> 00:31.360\n<v Speaker 2>I flew with Contoso Airways on flight CA123.\n\n00:32.080 --> 00:35.040\n<v Speaker 2>The departure date was March 25th at 9 a.m.\n\n00:35.840 --> 00:38.960\n<v Speaker 1>I apologize for any inconvenience you experienced.\n\n00:39.760 --> 00:43.360\n<v Speaker 1>Could you please let me know what specifically went wrong during your flight?\n\n00:44.160 --> 00:48.240\n<v Speaker 2>The flight was delayed for several hours due to technical issues with the aircraft.\n\n00:49.040 --> 00:52.160\n<v Speaker 2>It caused me to miss an important meeting in Los Angeles.\n\n00:52.960 --> 00:56.480\n<v Speaker 1>I understand how frustrating that must have been, John.\n\n00:57.280 --> 01:00.160\n<v Speaker 1>Let me check what options we have to address this issue.\n\n01:01.040 --> 01:02.560\n<v Speaker 1>Please hold on for a moment.\n\n01:03.360 --> 01:04.960\n<v Speaker 2>Thank you, Isabella.\n\n01:05.760 --> 01:07.200\n<v Speaker 2>I appreciate your help.\n\n01:08.000 --> 01:13.840\n<v Speaker 1>I've looked into your situation, John, and I apologize for the inconvenience caused by the flight delay.\n\n01:14.640 --> 01:22.240\n<v Speaker 1>I have reached out to Contoso Airways on your behalf, and they have offered to provide you with a partial refund for the inconvenience caused.\n\n01:23.040 --> 01:25.120\n<v Speaker 2>That's great to hear, Isabella.\n\n01:26.000 --> 01:29.040\n<v Speaker 2>I really appreciate your assistance in resolving this matter.\n\n01:29.840 --> 01:30.480\n<v Speaker 2>Thank you.\n\n01:31.200 --> 01:32.880\n<v Speaker 1>You're welcome, John.\n\n01:33.680 --> 01:34.960\n<v Speaker 1>I'm glad I could help.\n\n01:35.760 --> 01:37.920\n<v Speaker 1>Is there anything else I can assist you with?\n\n01:38.800 --> 01:40.400\n<v Speaker 2>No, that's all for now.\n\n01:41.280 --> 01:44.400\n<v Speaker 2>Thank you again for your excellent service, Isabella.\n\n01:45.200 --> 01:47.040\n<v Speaker 1>It was my pleasure, John.\n\n01:47.840 --> 01:52.240\n<v Speaker 1>If you need any further assistance in the future, don't hesitate to reach out.\n\n01:53.040 --> 01:54.000\n<v Speaker 1>Have a great day!```",
#         "kind": "audioVisual",
#         "startTimeMs": 0,
#         "endTimeMs": 114669,
#         "transcriptPhrases": [
#           {
#             "speaker": "Speaker 1",
#             "startTimeMs": 80,
#             "endTimeMs": 2160,
#             "text": "Thank you for calling Woodgrove Travel.",
#             "confidence": 0.97,
#             "words": [
#               {
#                 "startTimeMs": 80,
#                 "endTimeMs": 400,
#                 "text": "Thank"
#               },
#               {
#                 "startTimeMs": 400,
#                 "endTimeMs": 560,
#                 "text": "you"
#               },
#               {
#                 "startTimeMs": 560,
#                 "endTimeMs": 720,
#                 "text": "for"
#               },
#               {
#                 "startTimeMs": 720,
#                 "endTimeMs": 1120,
#                 "text": "calling"
#               },
#               {
#                 "startTimeMs": 1120,
#                 "endTimeMs": 1680,
#                 "text": "Woodgrove"
#               },
#               {
#                 "startTimeMs": 1680,
#                 "endTimeMs": 2160,
#                 "text": "Travel."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 1",
#             "startTimeMs": 2960,
#             "endTimeMs": 4560,
#             "text": "My name is Isabella Taylor.",
#             "confidence": 0.97,
#             "words": [
#               {
#                 "startTimeMs": 2960,
#                 "endTimeMs": 3120,
#                 "text": "My"
#               },
#               {
#                 "startTimeMs": 3120,
#                 "endTimeMs": 3440,
#                 "text": "name"
#               },
#               {
#                 "startTimeMs": 3440,
#                 "endTimeMs": 3600,
#                 "text": "is"
#               },
#               {
#                 "startTimeMs": 3600,
#                 "endTimeMs": 4080,
#                 "text": "Isabella"
#               },
#               {
#                 "startTimeMs": 4080,
#                 "endTimeMs": 4560,
#                 "text": "Taylor."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 1",
#             "startTimeMs": 5360,
#             "endTimeMs": 6880,
#             "text": "How may I assist you today?",
#             "confidence": 0.97,
#             "words": [
#               {
#                 "startTimeMs": 5360,
#                 "endTimeMs": 5600,
#                 "text": "How"
#               },
#               {
#                 "startTimeMs": 5600,
#                 "endTimeMs": 5760,
#                 "text": "may"
#               },
#               {
#                 "startTimeMs": 5760,
#                 "endTimeMs": 5920,
#                 "text": "I"
#               },
#               {
#                 "startTimeMs": 5920,
#                 "endTimeMs": 6320,
#                 "text": "assist"
#               },
#               {
#                 "startTimeMs": 6320,
#                 "endTimeMs": 6480,
#                 "text": "you"
#               },
#               {
#                 "startTimeMs": 6480,
#                 "endTimeMs": 6880,
#                 "text": "today?"
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 2",
#             "startTimeMs": 7680,
#             "endTimeMs": 10240,
#             "text": "Hi Isabella, my name is John Smith.",
#             "confidence": 0.97,
#             "words": [
#               {
#                 "startTimeMs": 7680,
#                 "endTimeMs": 7920,
#                 "text": "Hi"
#               },
#               {
#                 "startTimeMs": 7920,
#                 "endTimeMs": 8560,
#                 "text": "Isabella,"
#               },
#               {
#                 "startTimeMs": 8880,
#                 "endTimeMs": 9040,
#                 "text": "my"
#               },
#               {
#                 "startTimeMs": 9040,
#                 "endTimeMs": 9360,
#                 "text": "name"
#               },
#               {
#                 "startTimeMs": 9360,
#                 "endTimeMs": 9520,
#                 "text": "is"
#               },
#               {
#                 "startTimeMs": 9520,
#                 "endTimeMs": 9840,
#                 "text": "John"
#               },
#               {
#                 "startTimeMs": 9840,
#                 "endTimeMs": 10240,
#                 "text": "Smith."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 2",
#             "startTimeMs": 11120,
#             "endTimeMs": 17920,
#             "text": "I recently traveled from New York City to Los Angeles on a business trip, and I had a terrible experience with my flight.",
#             "confidence": 0.97,
#             "words": [
#               {
#                 "startTimeMs": 11120,
#                 "endTimeMs": 11200,
#                 "text": "I"
#               },
#               {
#                 "startTimeMs": 11200,
#                 "endTimeMs": 11760,
#                 "text": "recently"
#               },
#               {
#                 "startTimeMs": 11760,
#                 "endTimeMs": 12200,
#                 "text": "traveled"
#               },
#               {
#                 "startTimeMs": 12200,
#                 "endTimeMs": 12400,
#                 "text": "from"
#               },
#               {
#                 "startTimeMs": 12400,
#                 "endTimeMs": 12560,
#                 "text": "New"
#               },
#               {
#                 "startTimeMs": 12560,
#                 "endTimeMs": 12880,
#                 "text": "York"
#               },
#               {
#                 "startTimeMs": 12880,
#                 "endTimeMs": 13200,
#                 "text": "City"
#               },
#               {
#                 "startTimeMs": 13200,
#                 "endTimeMs": 13320,
#                 "text": "to"
#               },
#               {
#                 "startTimeMs": 13320,
#                 "endTimeMs": 13680,
#                 "text": "Los"
#               },
#               {
#                 "startTimeMs": 13680,
#                 "endTimeMs": 14160,
#                 "text": "Angeles"
#               },
#               {
#                 "startTimeMs": 14160,
#                 "endTimeMs": 14320,
#                 "text": "on"
#               },
#               {
#                 "startTimeMs": 14320,
#                 "endTimeMs": 14360,
#                 "text": "a"
#               },
#               {
#                 "startTimeMs": 14360,
#                 "endTimeMs": 14800,
#                 "text": "business"
#               },
#               {
#                 "startTimeMs": 14800,
#                 "endTimeMs": 15200,
#                 "text": "trip,"
#               },
#               {
#                 "startTimeMs": 15520,
#                 "endTimeMs": 15720,
#                 "text": "and"
#               },
#               {
#                 "startTimeMs": 15720,
#                 "endTimeMs": 15760,
#                 "text": "I"
#               },
#               {
#                 "startTimeMs": 15760,
#                 "endTimeMs": 15960,
#                 "text": "had"
#               },
#               {
#                 "startTimeMs": 15960,
#                 "endTimeMs": 16000,
#                 "text": "a"
#               },
#               {
#                 "startTimeMs": 16000,
#                 "endTimeMs": 16480,
#                 "text": "terrible"
#               },
#               {
#                 "startTimeMs": 16480,
#                 "endTimeMs": 17120,
#                 "text": "experience"
#               },
#               {
#                 "startTimeMs": 17120,
#                 "endTimeMs": 17280,
#                 "text": "with"
#               },
#               {
#                 "startTimeMs": 17280,
#                 "endTimeMs": 17440,
#                 "text": "my"
#               },
#               {
#                 "startTimeMs": 17440,
#                 "endTimeMs": 17920,
#                 "text": "flight."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 1",
#             "startTimeMs": 18720,
#             "endTimeMs": 20880,
#             "text": "I'm sorry to hear that, John.",
#             "confidence": 0.97,
#             "words": [
#               {
#                 "startTimeMs": 18720,
#                 "endTimeMs": 18960,
#                 "text": "I'm"
#               },
#               {
#                 "startTimeMs": 18960,
#                 "endTimeMs": 19280,
#                 "text": "sorry"
#               },
#               {
#                 "startTimeMs": 19280,
#                 "endTimeMs": 19440,
#                 "text": "to"
#               },
#               {
#                 "startTimeMs": 19440,
#                 "endTimeMs": 19680,
#                 "text": "hear"
#               },
#               {
#                 "startTimeMs": 19680,
#                 "endTimeMs": 20000,
#                 "text": "that,"
#               },
#               {
#                 "startTimeMs": 20320,
#                 "endTimeMs": 20880,
#                 "text": "John."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 1",
#             "startTimeMs": 21680,
#             "endTimeMs": 27200,
#             "text": "Could you please provide me with the details of your flight, such as the airline name and flight number?",
#             "confidence": 0.97,
#             "words": [
#               {
#                 "startTimeMs": 21680,
#                 "endTimeMs": 21880,
#                 "text": "Could"
#               },
#               {
#                 "startTimeMs": 21880,
#                 "endTimeMs": 22040,
#                 "text": "you"
#               },
#               {
#                 "startTimeMs": 22040,
#                 "endTimeMs": 22320,
#                 "text": "please"
#               },
#               {
#                 "startTimeMs": 22320,
#                 "endTimeMs": 22760,
#                 "text": "provide"
#               },
#               {
#                 "startTimeMs": 22760,
#                 "endTimeMs": 22960,
#                 "text": "me"
#               },
#               {
#                 "startTimeMs": 22960,
#                 "endTimeMs": 23160,
#                 "text": "with"
#               },
#               {
#                 "startTimeMs": 23160,
#                 "endTimeMs": 23240,
#                 "text": "the"
#               },
#               {
#                 "startTimeMs": 23240,
#                 "endTimeMs": 23760,
#                 "text": "details"
#               },
#               {
#                 "startTimeMs": 23760,
#                 "endTimeMs": 23920,
#                 "text": "of"
#               },
#               {
#                 "startTimeMs": 23920,
#                 "endTimeMs": 24080,
#                 "text": "your"
#               },
#               {
#                 "startTimeMs": 24080,
#                 "endTimeMs": 24480,
#                 "text": "flight,"
#               },
#               {
#                 "startTimeMs": 24800,
#                 "endTimeMs": 25200,
#                 "text": "such"
#               },
#               {
#                 "startTimeMs": 25200,
#                 "endTimeMs": 25360,
#                 "text": "as"
#               },
#               {
#                 "startTimeMs": 25360,
#                 "endTimeMs": 25480,
#                 "text": "the"
#               },
#               {
#                 "startTimeMs": 25520,
#                 "endTimeMs": 25880,
#                 "text": "airline"
#               },
#               {
#                 "startTimeMs": 25880,
#                 "endTimeMs": 26240,
#                 "text": "name"
#               },
#               {
#                 "startTimeMs": 26240,
#                 "endTimeMs": 26400,
#                 "text": "and"
#               },
#               {
#                 "startTimeMs": 26400,
#                 "endTimeMs": 26720,
#                 "text": "flight"
#               },
#               {
#                 "startTimeMs": 26720,
#                 "endTimeMs": 27200,
#                 "text": "number?"
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 2",
#             "startTimeMs": 28000,
#             "endTimeMs": 31360,
#             "text": "I flew with Contoso Airways on flight CA123.",
#             "confidence": 0.949,
#             "words": [
#               {
#                 "startTimeMs": 28000,
#                 "endTimeMs": 28080,
#                 "text": "I"
#               },
#               {
#                 "startTimeMs": 28080,
#                 "endTimeMs": 28320,
#                 "text": "flew"
#               },
#               {
#                 "startTimeMs": 28320,
#                 "endTimeMs": 28520,
#                 "text": "with"
#               },
#               {
#                 "startTimeMs": 28520,
#                 "endTimeMs": 29120,
#                 "text": "Contoso"
#               },
#               {
#                 "startTimeMs": 29120,
#                 "endTimeMs": 29600,
#                 "text": "Airways"
#               },
#               {
#                 "startTimeMs": 29600,
#                 "endTimeMs": 29800,
#                 "text": "on"
#               },
#               {
#                 "startTimeMs": 29800,
#                 "endTimeMs": 30160,
#                 "text": "flight"
#               },
#               {
#                 "startTimeMs": 30160,
#                 "endTimeMs": 31360,
#                 "text": "CA123."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 2",
#             "startTimeMs": 32080,
#             "endTimeMs": 35040,
#             "text": "The departure date was March 25th at 9 a.m.",
#             "confidence": 0.949,
#             "words": [
#               {
#                 "startTimeMs": 32080,
#                 "endTimeMs": 32240,
#                 "text": "The"
#               },
#               {
#                 "startTimeMs": 32240,
#                 "endTimeMs": 32800,
#                 "text": "departure"
#               },
#               {
#                 "startTimeMs": 32800,
#                 "endTimeMs": 33040,
#                 "text": "date"
#               },
#               {
#                 "startTimeMs": 33040,
#                 "endTimeMs": 33200,
#                 "text": "was"
#               },
#               {
#                 "startTimeMs": 33200,
#                 "endTimeMs": 33520,
#                 "text": "March"
#               },
#               {
#                 "startTimeMs": 33520,
#                 "endTimeMs": 34240,
#                 "text": "25th"
#               },
#               {
#                 "startTimeMs": 34240,
#                 "endTimeMs": 34320,
#                 "text": "at"
#               },
#               {
#                 "startTimeMs": 34320,
#                 "endTimeMs": 34640,
#                 "text": "9"
#               },
#               {
#                 "startTimeMs": 34640,
#                 "endTimeMs": 35040,
#                 "text": "a.m."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 1",
#             "startTimeMs": 35840,
#             "endTimeMs": 38960,
#             "text": "I apologize for any inconvenience you experienced.",
#             "confidence": 0.949,
#             "words": [
#               {
#                 "startTimeMs": 35840,
#                 "endTimeMs": 36080,
#                 "text": "I"
#               },
#               {
#                 "startTimeMs": 36080,
#                 "endTimeMs": 36800,
#                 "text": "apologize"
#               },
#               {
#                 "startTimeMs": 36800,
#                 "endTimeMs": 37040,
#                 "text": "for"
#               },
#               {
#                 "startTimeMs": 37040,
#                 "endTimeMs": 37280,
#                 "text": "any"
#               },
#               {
#                 "startTimeMs": 37280,
#                 "endTimeMs": 38000,
#                 "text": "inconvenience"
#               },
#               {
#                 "startTimeMs": 38000,
#                 "endTimeMs": 38160,
#                 "text": "you"
#               },
#               {
#                 "startTimeMs": 38160,
#                 "endTimeMs": 38960,
#                 "text": "experienced."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 1",
#             "startTimeMs": 39760,
#             "endTimeMs": 43360,
#             "text": "Could you please let me know what specifically went wrong during your flight?",
#             "confidence": 0.949,
#             "words": [
#               {
#                 "startTimeMs": 39760,
#                 "endTimeMs": 40000,
#                 "text": "Could"
#               },
#               {
#                 "startTimeMs": 40000,
#                 "endTimeMs": 40160,
#                 "text": "you"
#               },
#               {
#                 "startTimeMs": 40160,
#                 "endTimeMs": 40480,
#                 "text": "please"
#               },
#               {
#                 "startTimeMs": 40480,
#                 "endTimeMs": 40720,
#                 "text": "let"
#               },
#               {
#                 "startTimeMs": 40720,
#                 "endTimeMs": 40880,
#                 "text": "me"
#               },
#               {
#                 "startTimeMs": 40880,
#                 "endTimeMs": 41040,
#                 "text": "know"
#               },
#               {
#                 "startTimeMs": 41040,
#                 "endTimeMs": 41280,
#                 "text": "what"
#               },
#               {
#                 "startTimeMs": 41280,
#                 "endTimeMs": 41920,
#                 "text": "specifically"
#               },
#               {
#                 "startTimeMs": 41920,
#                 "endTimeMs": 42200,
#                 "text": "went"
#               },
#               {
#                 "startTimeMs": 42200,
#                 "endTimeMs": 42480,
#                 "text": "wrong"
#               },
#               {
#                 "startTimeMs": 42480,
#                 "endTimeMs": 42800,
#                 "text": "during"
#               },
#               {
#                 "startTimeMs": 42800,
#                 "endTimeMs": 42960,
#                 "text": "your"
#               },
#               {
#                 "startTimeMs": 42960,
#                 "endTimeMs": 43360,
#                 "text": "flight?"
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 2",
#             "startTimeMs": 44160,
#             "endTimeMs": 48240,
#             "text": "The flight was delayed for several hours due to technical issues with the aircraft.",
#             "confidence": 0.949,
#             "words": [
#               {
#                 "startTimeMs": 44160,
#                 "endTimeMs": 44320,
#                 "text": "The"
#               },
#               {
#                 "startTimeMs": 44320,
#                 "endTimeMs": 44640,
#                 "text": "flight"
#               },
#               {
#                 "startTimeMs": 44640,
#                 "endTimeMs": 44800,
#                 "text": "was"
#               },
#               {
#                 "startTimeMs": 44800,
#                 "endTimeMs": 45200,
#                 "text": "delayed"
#               },
#               {
#                 "startTimeMs": 45200,
#                 "endTimeMs": 45360,
#                 "text": "for"
#               },
#               {
#                 "startTimeMs": 45360,
#                 "endTimeMs": 45760,
#                 "text": "several"
#               },
#               {
#                 "startTimeMs": 45760,
#                 "endTimeMs": 46080,
#                 "text": "hours"
#               },
#               {
#                 "startTimeMs": 46080,
#                 "endTimeMs": 46240,
#                 "text": "due"
#               },
#               {
#                 "startTimeMs": 46240,
#                 "endTimeMs": 46360,
#                 "text": "to"
#               },
#               {
#                 "startTimeMs": 46360,
#                 "endTimeMs": 46960,
#                 "text": "technical"
#               },
#               {
#                 "startTimeMs": 46960,
#                 "endTimeMs": 47360,
#                 "text": "issues"
#               },
#               {
#                 "startTimeMs": 47360,
#                 "endTimeMs": 47480,
#                 "text": "with"
#               },
#               {
#                 "startTimeMs": 47480,
#                 "endTimeMs": 47560,
#                 "text": "the"
#               },
#               {
#                 "startTimeMs": 47600,
#                 "endTimeMs": 48240,
#                 "text": "aircraft."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 2",
#             "startTimeMs": 49040,
#             "endTimeMs": 52160,
#             "text": "It caused me to miss an important meeting in Los Angeles.",
#             "confidence": 0.949,
#             "words": [
#               {
#                 "startTimeMs": 49040,
#                 "endTimeMs": 49280,
#                 "text": "It"
#               },
#               {
#                 "startTimeMs": 49280,
#                 "endTimeMs": 49520,
#                 "text": "caused"
#               },
#               {
#                 "startTimeMs": 49560,
#                 "endTimeMs": 49760,
#                 "text": "me"
#               },
#               {
#                 "startTimeMs": 49760,
#                 "endTimeMs": 49880,
#                 "text": "to"
#               },
#               {
#                 "startTimeMs": 49880,
#                 "endTimeMs": 50120,
#                 "text": "miss"
#               },
#               {
#                 "startTimeMs": 50120,
#                 "endTimeMs": 50240,
#                 "text": "an"
#               },
#               {
#                 "startTimeMs": 50240,
#                 "endTimeMs": 50720,
#                 "text": "important"
#               },
#               {
#                 "startTimeMs": 50720,
#                 "endTimeMs": 51040,
#                 "text": "meeting"
#               },
#               {
#                 "startTimeMs": 51040,
#                 "endTimeMs": 51200,
#                 "text": "in"
#               },
#               {
#                 "startTimeMs": 51200,
#                 "endTimeMs": 51520,
#                 "text": "Los"
#               },
#               {
#                 "startTimeMs": 51520,
#                 "endTimeMs": 52160,
#                 "text": "Angeles."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 1",
#             "startTimeMs": 52960,
#             "endTimeMs": 56480,
#             "text": "I understand how frustrating that must have been, John.",
#             "confidence": 0.949,
#             "words": [
#               {
#                 "startTimeMs": 52960,
#                 "endTimeMs": 53160,
#                 "text": "I"
#               },
#               {
#                 "startTimeMs": 53160,
#                 "endTimeMs": 53760,
#                 "text": "understand"
#               },
#               {
#                 "startTimeMs": 53760,
#                 "endTimeMs": 54000,
#                 "text": "how"
#               },
#               {
#                 "startTimeMs": 54000,
#                 "endTimeMs": 54680,
#                 "text": "frustrating"
#               },
#               {
#                 "startTimeMs": 54680,
#                 "endTimeMs": 54880,
#                 "text": "that"
#               },
#               {
#                 "startTimeMs": 54880,
#                 "endTimeMs": 55160,
#                 "text": "must"
#               },
#               {
#                 "startTimeMs": 55160,
#                 "endTimeMs": 55280,
#                 "text": "have"
#               },
#               {
#                 "startTimeMs": 55280,
#                 "endTimeMs": 55680,
#                 "text": "been,"
#               },
#               {
#                 "startTimeMs": 56000,
#                 "endTimeMs": 56480,
#                 "text": "John."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 1",
#             "startTimeMs": 57280,
#             "endTimeMs": 60160,
#             "text": "Let me check what options we have to address this issue.",
#             "confidence": 0.978,
#             "words": [
#               {
#                 "startTimeMs": 57280,
#                 "endTimeMs": 57520,
#                 "text": "Let"
#               },
#               {
#                 "startTimeMs": 57520,
#                 "endTimeMs": 57680,
#                 "text": "me"
#               },
#               {
#                 "startTimeMs": 57680,
#                 "endTimeMs": 57880,
#                 "text": "check"
#               },
#               {
#                 "startTimeMs": 57880,
#                 "endTimeMs": 58160,
#                 "text": "what"
#               },
#               {
#                 "startTimeMs": 58160,
#                 "endTimeMs": 58640,
#                 "text": "options"
#               },
#               {
#                 "startTimeMs": 58640,
#                 "endTimeMs": 58800,
#                 "text": "we"
#               },
#               {
#                 "startTimeMs": 58800,
#                 "endTimeMs": 58960,
#                 "text": "have"
#               },
#               {
#                 "startTimeMs": 58960,
#                 "endTimeMs": 59160,
#                 "text": "to"
#               },
#               {
#                 "startTimeMs": 59160,
#                 "endTimeMs": 59520,
#                 "text": "address"
#               },
#               {
#                 "startTimeMs": 59520,
#                 "endTimeMs": 59760,
#                 "text": "this"
#               },
#               {
#                 "startTimeMs": 59760,
#                 "endTimeMs": 60160,
#                 "text": "issue."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 1",
#             "startTimeMs": 61040,
#             "endTimeMs": 62560,
#             "text": "Please hold on for a moment.",
#             "confidence": 0.978,
#             "words": [
#               {
#                 "startTimeMs": 61040,
#                 "endTimeMs": 61360,
#                 "text": "Please"
#               },
#               {
#                 "startTimeMs": 61360,
#                 "endTimeMs": 61680,
#                 "text": "hold"
#               },
#               {
#                 "startTimeMs": 61680,
#                 "endTimeMs": 61840,
#                 "text": "on"
#               },
#               {
#                 "startTimeMs": 61840,
#                 "endTimeMs": 62040,
#                 "text": "for"
#               },
#               {
#                 "startTimeMs": 62040,
#                 "endTimeMs": 62080,
#                 "text": "a"
#               },
#               {
#                 "startTimeMs": 62080,
#                 "endTimeMs": 62560,
#                 "text": "moment."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 2",
#             "startTimeMs": 63360,
#             "endTimeMs": 64960,
#             "text": "Thank you, Isabella.",
#             "confidence": 0.978,
#             "words": [
#               {
#                 "startTimeMs": 63360,
#                 "endTimeMs": 63680,
#                 "text": "Thank"
#               },
#               {
#                 "startTimeMs": 63680,
#                 "endTimeMs": 63920,
#                 "text": "you,"
#               },
#               {
#                 "startTimeMs": 64320,
#                 "endTimeMs": 64960,
#                 "text": "Isabella."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 2",
#             "startTimeMs": 65760,
#             "endTimeMs": 67200,
#             "text": "I appreciate your help.",
#             "confidence": 0.978,
#             "words": [
#               {
#                 "startTimeMs": 65760,
#                 "endTimeMs": 65920,
#                 "text": "I"
#               },
#               {
#                 "startTimeMs": 65920,
#                 "endTimeMs": 66640,
#                 "text": "appreciate"
#               },
#               {
#                 "startTimeMs": 66640,
#                 "endTimeMs": 66800,
#                 "text": "your"
#               },
#               {
#                 "startTimeMs": 66800,
#                 "endTimeMs": 67200,
#                 "text": "help."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 1",
#             "startTimeMs": 68000,
#             "endTimeMs": 73840,
#             "text": "I've looked into your situation, John, and I apologize for the inconvenience caused by the flight delay.",
#             "confidence": 0.978,
#             "words": [
#               {
#                 "startTimeMs": 68000,
#                 "endTimeMs": 68240,
#                 "text": "I've"
#               },
#               {
#                 "startTimeMs": 68240,
#                 "endTimeMs": 68480,
#                 "text": "looked"
#               },
#               {
#                 "startTimeMs": 68480,
#                 "endTimeMs": 68760,
#                 "text": "into"
#               },
#               {
#                 "startTimeMs": 68760,
#                 "endTimeMs": 68960,
#                 "text": "your"
#               },
#               {
#                 "startTimeMs": 68960,
#                 "endTimeMs": 69760,
#                 "text": "situation,"
#               },
#               {
#                 "startTimeMs": 69840,
#                 "endTimeMs": 70320,
#                 "text": "John,"
#               },
#               {
#                 "startTimeMs": 70320,
#                 "endTimeMs": 70600,
#                 "text": "and"
#               },
#               {
#                 "startTimeMs": 70600,
#                 "endTimeMs": 70720,
#                 "text": "I"
#               },
#               {
#                 "startTimeMs": 70720,
#                 "endTimeMs": 71440,
#                 "text": "apologize"
#               },
#               {
#                 "startTimeMs": 71440,
#                 "endTimeMs": 71600,
#                 "text": "for"
#               },
#               {
#                 "startTimeMs": 71600,
#                 "endTimeMs": 71720,
#                 "text": "the"
#               },
#               {
#                 "startTimeMs": 71720,
#                 "endTimeMs": 72480,
#                 "text": "inconvenience"
#               },
#               {
#                 "startTimeMs": 72480,
#                 "endTimeMs": 72840,
#                 "text": "caused"
#               },
#               {
#                 "startTimeMs": 72840,
#                 "endTimeMs": 73040,
#                 "text": "by"
#               },
#               {
#                 "startTimeMs": 73040,
#                 "endTimeMs": 73120,
#                 "text": "the"
#               },
#               {
#                 "startTimeMs": 73120,
#                 "endTimeMs": 73440,
#                 "text": "flight"
#               },
#               {
#                 "startTimeMs": 73440,
#                 "endTimeMs": 73840,
#                 "text": "delay."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 1",
#             "startTimeMs": 74640,
#             "endTimeMs": 82240,
#             "text": "I have reached out to Contoso Airways on your behalf, and they have offered to provide you with a partial refund for the inconvenience caused.",
#             "confidence": 0.978,
#             "words": [
#               {
#                 "startTimeMs": 74640,
#                 "endTimeMs": 74800,
#                 "text": "I"
#               },
#               {
#                 "startTimeMs": 74800,
#                 "endTimeMs": 74960,
#                 "text": "have"
#               },
#               {
#                 "startTimeMs": 74960,
#                 "endTimeMs": 75360,
#                 "text": "reached"
#               },
#               {
#                 "startTimeMs": 75360,
#                 "endTimeMs": 75480,
#                 "text": "out"
#               },
#               {
#                 "startTimeMs": 75480,
#                 "endTimeMs": 75680,
#                 "text": "to"
#               },
#               {
#                 "startTimeMs": 75680,
#                 "endTimeMs": 76320,
#                 "text": "Contoso"
#               },
#               {
#                 "startTimeMs": 76320,
#                 "endTimeMs": 76800,
#                 "text": "Airways"
#               },
#               {
#                 "startTimeMs": 76800,
#                 "endTimeMs": 76960,
#                 "text": "on"
#               },
#               {
#                 "startTimeMs": 76960,
#                 "endTimeMs": 77120,
#                 "text": "your"
#               },
#               {
#                 "startTimeMs": 77120,
#                 "endTimeMs": 77680,
#                 "text": "behalf,"
#               },
#               {
#                 "startTimeMs": 78000,
#                 "endTimeMs": 78280,
#                 "text": "and"
#               },
#               {
#                 "startTimeMs": 78280,
#                 "endTimeMs": 78400,
#                 "text": "they"
#               },
#               {
#                 "startTimeMs": 78400,
#                 "endTimeMs": 78560,
#                 "text": "have"
#               },
#               {
#                 "startTimeMs": 78560,
#                 "endTimeMs": 78920,
#                 "text": "offered"
#               },
#               {
#                 "startTimeMs": 78920,
#                 "endTimeMs": 79040,
#                 "text": "to"
#               },
#               {
#                 "startTimeMs": 79040,
#                 "endTimeMs": 79440,
#                 "text": "provide"
#               },
#               {
#                 "startTimeMs": 79440,
#                 "endTimeMs": 79600,
#                 "text": "you"
#               },
#               {
#                 "startTimeMs": 79600,
#                 "endTimeMs": 79840,
#                 "text": "with"
#               },
#               {
#                 "startTimeMs": 79840,
#                 "endTimeMs": 79880,
#                 "text": "a"
#               },
#               {
#                 "startTimeMs": 79880,
#                 "endTimeMs": 80320,
#                 "text": "partial"
#               },
#               {
#                 "startTimeMs": 80320,
#                 "endTimeMs": 80760,
#                 "text": "refund"
#               },
#               {
#                 "startTimeMs": 80760,
#                 "endTimeMs": 80880,
#                 "text": "for"
#               },
#               {
#                 "startTimeMs": 80880,
#                 "endTimeMs": 81000,
#                 "text": "the"
#               },
#               {
#                 "startTimeMs": 81000,
#                 "endTimeMs": 81760,
#                 "text": "inconvenience"
#               },
#               {
#                 "startTimeMs": 81760,
#                 "endTimeMs": 82240,
#                 "text": "caused."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 2",
#             "startTimeMs": 83040,
#             "endTimeMs": 85120,
#             "text": "That's great to hear, Isabella.",
#             "confidence": 0.978,
#             "words": [
#               {
#                 "startTimeMs": 83040,
#                 "endTimeMs": 83360,
#                 "text": "That's"
#               },
#               {
#                 "startTimeMs": 83360,
#                 "endTimeMs": 83640,
#                 "text": "great"
#               },
#               {
#                 "startTimeMs": 83640,
#                 "endTimeMs": 83760,
#                 "text": "to"
#               },
#               {
#                 "startTimeMs": 83760,
#                 "endTimeMs": 84160,
#                 "text": "hear,"
#               },
#               {
#                 "startTimeMs": 84480,
#                 "endTimeMs": 85120,
#                 "text": "Isabella."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 2",
#             "startTimeMs": 86000,
#             "endTimeMs": 89040,
#             "text": "I really appreciate your assistance in resolving this matter.",
#             "confidence": 0.963,
#             "words": [
#               {
#                 "startTimeMs": 86000,
#                 "endTimeMs": 86080,
#                 "text": "I"
#               },
#               {
#                 "startTimeMs": 86080,
#                 "endTimeMs": 86400,
#                 "text": "really"
#               },
#               {
#                 "startTimeMs": 86400,
#                 "endTimeMs": 87040,
#                 "text": "appreciate"
#               },
#               {
#                 "startTimeMs": 87040,
#                 "endTimeMs": 87280,
#                 "text": "your"
#               },
#               {
#                 "startTimeMs": 87280,
#                 "endTimeMs": 87760,
#                 "text": "assistance"
#               },
#               {
#                 "startTimeMs": 87760,
#                 "endTimeMs": 87920,
#                 "text": "in"
#               },
#               {
#                 "startTimeMs": 87920,
#                 "endTimeMs": 88400,
#                 "text": "resolving"
#               },
#               {
#                 "startTimeMs": 88400,
#                 "endTimeMs": 88640,
#                 "text": "this"
#               },
#               {
#                 "startTimeMs": 88640,
#                 "endTimeMs": 89040,
#                 "text": "matter."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 2",
#             "startTimeMs": 89840,
#             "endTimeMs": 90480,
#             "text": "Thank you.",
#             "confidence": 0.963,
#             "words": [
#               {
#                 "startTimeMs": 89840,
#                 "endTimeMs": 90160,
#                 "text": "Thank"
#               },
#               {
#                 "startTimeMs": 90160,
#                 "endTimeMs": 90480,
#                 "text": "you."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 1",
#             "startTimeMs": 91200,
#             "endTimeMs": 92880,
#             "text": "You're welcome, John.",
#             "confidence": 0.963,
#             "words": [
#               {
#                 "startTimeMs": 91200,
#                 "endTimeMs": 91520,
#                 "text": "You're"
#               },
#               {
#                 "startTimeMs": 91520,
#                 "endTimeMs": 92080,
#                 "text": "welcome,"
#               },
#               {
#                 "startTimeMs": 92400,
#                 "endTimeMs": 92880,
#                 "text": "John."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 1",
#             "startTimeMs": 93680,
#             "endTimeMs": 94960,
#             "text": "I'm glad I could help.",
#             "confidence": 0.963,
#             "words": [
#               {
#                 "startTimeMs": 93680,
#                 "endTimeMs": 93920,
#                 "text": "I'm"
#               },
#               {
#                 "startTimeMs": 93920,
#                 "endTimeMs": 94240,
#                 "text": "glad"
#               },
#               {
#                 "startTimeMs": 94240,
#                 "endTimeMs": 94320,
#                 "text": "I"
#               },
#               {
#                 "startTimeMs": 94320,
#                 "endTimeMs": 94560,
#                 "text": "could"
#               },
#               {
#                 "startTimeMs": 94560,
#                 "endTimeMs": 94960,
#                 "text": "help."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 1",
#             "startTimeMs": 95760,
#             "endTimeMs": 97920,
#             "text": "Is there anything else I can assist you with?",
#             "confidence": 0.963,
#             "words": [
#               {
#                 "startTimeMs": 95760,
#                 "endTimeMs": 96000,
#                 "text": "Is"
#               },
#               {
#                 "startTimeMs": 96000,
#                 "endTimeMs": 96160,
#                 "text": "there"
#               },
#               {
#                 "startTimeMs": 96160,
#                 "endTimeMs": 96600,
#                 "text": "anything"
#               },
#               {
#                 "startTimeMs": 96600,
#                 "endTimeMs": 96920,
#                 "text": "else"
#               },
#               {
#                 "startTimeMs": 96920,
#                 "endTimeMs": 97040,
#                 "text": "I"
#               },
#               {
#                 "startTimeMs": 97040,
#                 "endTimeMs": 97200,
#                 "text": "can"
#               },
#               {
#                 "startTimeMs": 97200,
#                 "endTimeMs": 97600,
#                 "text": "assist"
#               },
#               {
#                 "startTimeMs": 97600,
#                 "endTimeMs": 97680,
#                 "text": "you"
#               },
#               {
#                 "startTimeMs": 97680,
#                 "endTimeMs": 97920,
#                 "text": "with?"
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 2",
#             "startTimeMs": 98800,
#             "endTimeMs": 100400,
#             "text": "No, that's all for now.",
#             "confidence": 0.963,
#             "words": [
#               {
#                 "startTimeMs": 98800,
#                 "endTimeMs": 99200,
#                 "text": "No,"
#               },
#               {
#                 "startTimeMs": 99520,
#                 "endTimeMs": 99840,
#                 "text": "that's"
#               },
#               {
#                 "startTimeMs": 99840,
#                 "endTimeMs": 100000,
#                 "text": "all"
#               },
#               {
#                 "startTimeMs": 100000,
#                 "endTimeMs": 100160,
#                 "text": "for"
#               },
#               {
#                 "startTimeMs": 100160,
#                 "endTimeMs": 100400,
#                 "text": "now."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 2",
#             "startTimeMs": 101280,
#             "endTimeMs": 104400,
#             "text": "Thank you again for your excellent service, Isabella.",
#             "confidence": 0.963,
#             "words": [
#               {
#                 "startTimeMs": 101280,
#                 "endTimeMs": 101600,
#                 "text": "Thank"
#               },
#               {
#                 "startTimeMs": 101600,
#                 "endTimeMs": 101800,
#                 "text": "you"
#               },
#               {
#                 "startTimeMs": 101800,
#                 "endTimeMs": 102080,
#                 "text": "again"
#               },
#               {
#                 "startTimeMs": 102080,
#                 "endTimeMs": 102240,
#                 "text": "for"
#               },
#               {
#                 "startTimeMs": 102240,
#                 "endTimeMs": 102400,
#                 "text": "your"
#               },
#               {
#                 "startTimeMs": 102400,
#                 "endTimeMs": 102880,
#                 "text": "excellent"
#               },
#               {
#                 "startTimeMs": 102880,
#                 "endTimeMs": 103440,
#                 "text": "service,"
#               },
#               {
#                 "startTimeMs": 103760,
#                 "endTimeMs": 104400,
#                 "text": "Isabella."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 1",
#             "startTimeMs": 105200,
#             "endTimeMs": 107040,
#             "text": "It was my pleasure, John.",
#             "confidence": 0.963,
#             "words": [
#               {
#                 "startTimeMs": 105200,
#                 "endTimeMs": 105360,
#                 "text": "It"
#               },
#               {
#                 "startTimeMs": 105360,
#                 "endTimeMs": 105600,
#                 "text": "was"
#               },
#               {
#                 "startTimeMs": 105600,
#                 "endTimeMs": 105760,
#                 "text": "my"
#               },
#               {
#                 "startTimeMs": 105760,
#                 "endTimeMs": 106240,
#                 "text": "pleasure,"
#               },
#               {
#                 "startTimeMs": 106560,
#                 "endTimeMs": 107040,
#                 "text": "John."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 1",
#             "startTimeMs": 107840,
#             "endTimeMs": 112240,
#             "text": "If you need any further assistance in the future, don't hesitate to reach out.",
#             "confidence": 0.963,
#             "words": [
#               {
#                 "startTimeMs": 107840,
#                 "endTimeMs": 108080,
#                 "text": "If"
#               },
#               {
#                 "startTimeMs": 108080,
#                 "endTimeMs": 108160,
#                 "text": "you"
#               },
#               {
#                 "startTimeMs": 108160,
#                 "endTimeMs": 108440,
#                 "text": "need"
#               },
#               {
#                 "startTimeMs": 108440,
#                 "endTimeMs": 108640,
#                 "text": "any"
#               },
#               {
#                 "startTimeMs": 108640,
#                 "endTimeMs": 109080,
#                 "text": "further"
#               },
#               {
#                 "startTimeMs": 109080,
#                 "endTimeMs": 109600,
#                 "text": "assistance"
#               },
#               {
#                 "startTimeMs": 109600,
#                 "endTimeMs": 109760,
#                 "text": "in"
#               },
#               {
#                 "startTimeMs": 109760,
#                 "endTimeMs": 109840,
#                 "text": "the"
#               },
#               {
#                 "startTimeMs": 109840,
#                 "endTimeMs": 110400,
#                 "text": "future,"
#               },
#               {
#                 "startTimeMs": 110720,
#                 "endTimeMs": 111000,
#                 "text": "don't"
#               },
#               {
#                 "startTimeMs": 111000,
#                 "endTimeMs": 111480,
#                 "text": "hesitate"
#               },
#               {
#                 "startTimeMs": 111480,
#                 "endTimeMs": 111640,
#                 "text": "to"
#               },
#               {
#                 "startTimeMs": 111640,
#                 "endTimeMs": 111920,
#                 "text": "reach"
#               },
#               {
#                 "startTimeMs": 111920,
#                 "endTimeMs": 112240,
#                 "text": "out."
#               }
#             ],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "Speaker 1",
#             "startTimeMs": 113040,
#             "endTimeMs": 114000,
#             "text": "Have a great day!",
#             "confidence": 0.963,
#             "words": [
#               {
#                 "startTimeMs": 113040,
#                 "endTimeMs": 113320,
#                 "text": "Have"
#               },
#               {
#                 "startTimeMs": 113320,
#                 "endTimeMs": 113360,
#                 "text": "a"
#               },
#               {
#                 "startTimeMs": 113360,
#                 "endTimeMs": 113680,
#                 "text": "great"
#               },
#               {
#                 "startTimeMs": 113680,
#                 "endTimeMs": 114000,
#                 "text": "day!"
#               }
#             ],
#             "locale": "en-US"
#           }
#         ]
#       }
#     ]
#   }
# }
# INFO:python.content_understanding_client:Analyzer content-audio-sample-5a7f609f-dee6-49ac-9632-61a0c1ed18f5 deleted.
# <Response [204]>

# %% [markdown]
# ## Video Content
# Video output provides detailed information about audiovisual content, specifically video shots. Here are the key features it offers:
#
# 1. Shot Information: Each shot is defined by a start and end time, along with a unique identifier. For example, Shot 0:0.0 to 0:2.800 includes a transcript and key frames.
# 1. Transcript: The API includes a transcript of the audio, formatted in WEBVTT, which allows for easy synchronization with the video. It captures spoken content and specifies the timing of the dialogue.
# 1. Key Frames: It provides a series of key frames (images) that represent important moments in the video shot, allowing users to visualize the content at specific timestamps.
# 1. Description: Each shot is accompanied by a description, providing context about the visuals presented. This helps in understanding the scene or subject matter without watching the video.
# 1. Audio Visual Metadata: Details about the video such as dimensions (width and height), type (audiovisual), and the presence of key frame timestamps are included.
# 1. Transcript Phrases: The output includes specific phrases from the transcript, along with timing and speaker information, enhancing the usability for applications like closed captioning or search functionalities.

# %%
ANALYZER_ID = "content-video-sample-" + str(uuid.uuid4())
ANALYZER_TEMPLATE_FILE = '../analyzer_templates/content_video.json'
ANALYZER_SAMPLE_FILE = '../data/FlightSimulator.mp4'

# Create analyzer
response = client.begin_create_analyzer(ANALYZER_ID, analyzer_template_path=ANALYZER_TEMPLATE_FILE)
result = client.poll_result(response)

# Analyzer file
response = client.begin_analyze(ANALYZER_ID, file_location=ANALYZER_SAMPLE_FILE)
result = client.poll_result(response)

print(json.dumps(result, indent=2))

# Save keyframes (optional)
keyframe_ids = set()
result_data = result.get("result", {})
contents = result_data.get("contents", [])

# Iterate over contents to find keyframes if available
for content in contents:
    # Extract keyframe IDs from "markdown" if it exists and is a string
    markdown_content = content.get("markdown", "")
    if isinstance(markdown_content, str):
        keyframe_ids.update(re.findall(r"(keyFrame\.\d+)\.jpg", markdown_content))

# Output the results
print("Unique Keyframe IDs:", keyframe_ids)

# Save all keyframe images
for keyframe_id in keyframe_ids:
    save_image(keyframe_id, response)

# Delete analyzer
client.delete_analyzer(ANALYZER_ID)
# Out:
# INFO:python.content_understanding_client:Analyzer content-video-sample-cd025723-239e-42a1-a940-04c5cf0b4bc4 create request accepted.
# INFO:python.content_understanding_client:Request result is ready after 0.00 seconds.
# INFO:python.content_understanding_client:Analyzing file ../data/FlightSimulator.mp4 with analyzer: content-video-sample-cd025723-239e-42a1-a940-04c5cf0b4bc4
# INFO:python.content_understanding_client:Request 3bc14876-9098-4c8b-b132-bab60b5f6a64 in progress ...
# INFO:python.content_understanding_client:Request 3bc14876-9098-4c8b-b132-bab60b5f6a64 in progress ...
# INFO:python.content_understanding_client:Request 3bc14876-9098-4c8b-b132-bab60b5f6a64 in progress ...
# INFO:python.content_understanding_client:Request 3bc14876-9098-4c8b-b132-bab60b5f6a64 in progress ...
# INFO:python.content_understanding_client:Request 3bc14876-9098-4c8b-b132-bab60b5f6a64 in progress ...
# INFO:python.content_understanding_client:Request 3bc14876-9098-4c8b-b132-bab60b5f6a64 in progress ...
# INFO:python.content_understanding_client:Request result is ready after 14.87 seconds.
# {
#   "id": "3bc14876-9098-4c8b-b132-bab60b5f6a64",
#   "status": "Succeeded",
#   "result": {
#     "analyzerId": "content-video-sample-cd025723-239e-42a1-a940-04c5cf0b4bc4",
#     "apiVersion": "2024-12-01-preview",
#     "createdAt": "2025-03-06T16:49:27Z",
#     "warnings": [],
#     "contents": [
#       {
#         "markdown": "# Shot 00:00.000 => 00:01.467\n## Transcript\n```\nWEBVTT\n\n00:01.400 --> 00:06.560\n<v Speaker>When it comes to the neural TTS, in order to get a good voice, it's better to have good data.\n```\n## Key Frames\n- 00:00.726 ![](keyFrame.726.jpg)",
#         "fields": {},
#         "kind": "audioVisual",
#         "startTimeMs": 0,
#         "endTimeMs": 1467,
#         "width": 1080,
#         "height": 608,
#         "KeyFrameTimesMs": [
#           726
#         ],
#         "transcriptPhrases": [
#           {
#             "speaker": "speaker",
#             "startTimeMs": 1400,
#             "endTimeMs": 6560,
#             "text": "When it comes to the neural TTS, in order to get a good voice, it's better to have good data.",
#             "confidence": 1,
#             "words": [],
#             "locale": "en-US"
#           }
#         ]
#       },
#       {
#         "markdown": "# Shot 00:01.467 => 00:03.233\n## Transcript\n```\nWEBVTT\n\n00:01.400 --> 00:06.560\n<v Speaker>When it comes to the neural TTS, in order to get a good voice, it's better to have good data.\n```\n## Key Frames\n- 00:02.046 ![](keyFrame.2046.jpg)\n- 00:02.640 ![](keyFrame.2640.jpg)",
#         "fields": {},
#         "kind": "audioVisual",
#         "startTimeMs": 1467,
#         "endTimeMs": 3233,
#         "width": 1080,
#         "height": 608,
#         "KeyFrameTimesMs": [
#           2046,
#           2640
#         ],
#         "transcriptPhrases": [
#           {
#             "speaker": "speaker",
#             "startTimeMs": 1400,
#             "endTimeMs": 6560,
#             "text": "When it comes to the neural TTS, in order to get a good voice, it's better to have good data.",
#             "confidence": 1,
#             "words": [],
#             "locale": "en-US"
#           }
#         ]
#       },
#       {
#         "markdown": "# Shot 00:03.233 => 00:07.367\n## Transcript\n```\nWEBVTT\n\n00:01.400 --> 00:06.560\n<v Speaker>When it comes to the neural TTS, in order to get a good voice, it's better to have good data.\n```\n## Key Frames\n- 00:04.059 ![](keyFrame.4059.jpg)\n- 00:04.884 ![](keyFrame.4884.jpg)\n- 00:05.709 ![](keyFrame.5709.jpg)\n- 00:06.534 ![](keyFrame.6534.jpg)",
#         "fields": {},
#         "kind": "audioVisual",
#         "startTimeMs": 3233,
#         "endTimeMs": 7367,
#         "width": 1080,
#         "height": 608,
#         "KeyFrameTimesMs": [
#           4059,
#           4884,
#           5709,
#           6534
#         ],
#         "transcriptPhrases": [
#           {
#             "speaker": "speaker",
#             "startTimeMs": 1400,
#             "endTimeMs": 6560,
#             "text": "When it comes to the neural TTS, in order to get a good voice, it's better to have good data.",
#             "confidence": 1,
#             "words": [],
#             "locale": "en-US"
#           }
#         ]
#       },
#       {
#         "markdown": "# Shot 00:07.367 => 00:08.200\n## Transcript\n```\nWEBVTT\n\n00:07.600 --> 00:13.320\n<v Speaker>To achieve that, we build a universal TTS model based on 3,000 hours of data.\n```\n## Key Frames\n- 00:07.788 ![](keyFrame.7788.jpg)",
#         "fields": {},
#         "kind": "audioVisual",
#         "startTimeMs": 7367,
#         "endTimeMs": 8200,
#         "width": 1080,
#         "height": 608,
#         "KeyFrameTimesMs": [
#           7788
#         ],
#         "transcriptPhrases": [
#           {
#             "speaker": "speaker",
#             "startTimeMs": 7600,
#             "endTimeMs": 13320,
#             "text": "To achieve that, we build a universal TTS model based on 3,000 hours of data.",
#             "confidence": 1,
#             "words": [],
#             "locale": "en-US"
#           }
#         ]
#       },
#       {
#         "markdown": "# Shot 00:08.200 => 00:11.367\n## Transcript\n```\nWEBVTT\n\n00:07.600 --> 00:13.320\n<v Speaker>To achieve that, we build a universal TTS model based on 3,000 hours of data.\n```\n## Key Frames\n- 00:08.976 ![](keyFrame.8976.jpg)\n- 00:09.768 ![](keyFrame.9768.jpg)\n- 00:10.560 ![](keyFrame.10560.jpg)",
#         "fields": {},
#         "kind": "audioVisual",
#         "startTimeMs": 8200,
#         "endTimeMs": 11367,
#         "width": 1080,
#         "height": 608,
#         "KeyFrameTimesMs": [
#           8976,
#           9768,
#           10560
#         ],
#         "transcriptPhrases": [
#           {
#             "speaker": "speaker",
#             "startTimeMs": 7600,
#             "endTimeMs": 13320,
#             "text": "To achieve that, we build a universal TTS model based on 3,000 hours of data.",
#             "confidence": 1,
#             "words": [],
#             "locale": "en-US"
#           }
#         ]
#       },
#       {
#         "markdown": "# Shot 00:11.367 => 00:13.567\n## Transcript\n```\nWEBVTT\n\n00:07.600 --> 00:13.320\n<v Speaker>To achieve that, we build a universal TTS model based on 3,000 hours of data.\n00:13.440 --> 00:23.640\n<v Speaker>We actually accumulated tons of the data so that this universal model is able to capture the nuance of the audio and generate a more natural voice for the algorithm.\n```\n## Key Frames\n- 00:12.078 ![](keyFrame.12078.jpg)\n- 00:12.804 ![](keyFrame.12804.jpg)",
#         "fields": {},
#         "kind": "audioVisual",
#         "startTimeMs": 11367,
#         "endTimeMs": 13567,
#         "width": 1080,
#         "height": 608,
#         "KeyFrameTimesMs": [
#           12078,
#           12804
#         ],
#         "transcriptPhrases": [
#           {
#             "speaker": "speaker",
#             "startTimeMs": 7600,
#             "endTimeMs": 13320,
#             "text": "To achieve that, we build a universal TTS model based on 3,000 hours of data.",
#             "confidence": 1,
#             "words": [],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "speaker",
#             "startTimeMs": 13440,
#             "endTimeMs": 23640,
#             "text": "We actually accumulated tons of the data so that this universal model is able to capture the nuance of the audio and generate a more natural voice for the algorithm.",
#             "confidence": 1,
#             "words": [],
#             "locale": "en-US"
#           }
#         ]
#       },
#       {
#         "markdown": "# Shot 00:13.567 => 00:16.100\n## Transcript\n```\nWEBVTT\n\n00:13.440 --> 00:23.640\n<v Speaker>We actually accumulated tons of the data so that this universal model is able to capture the nuance of the audio and generate a more natural voice for the algorithm.\n```\n## Key Frames\n- 00:14.190 ![](keyFrame.14190.jpg)\n- 00:14.817 ![](keyFrame.14817.jpg)\n- 00:15.444 ![](keyFrame.15444.jpg)",
#         "fields": {},
#         "kind": "audioVisual",
#         "startTimeMs": 13567,
#         "endTimeMs": 16100,
#         "width": 1080,
#         "height": 608,
#         "KeyFrameTimesMs": [
#           14190,
#           14817,
#           15444
#         ],
#         "transcriptPhrases": [
#           {
#             "speaker": "speaker",
#             "startTimeMs": 13440,
#             "endTimeMs": 23640,
#             "text": "We actually accumulated tons of the data so that this universal model is able to capture the nuance of the audio and generate a more natural voice for the algorithm.",
#             "confidence": 1,
#             "words": [],
#             "locale": "en-US"
#           }
#         ]
#       },
#       {
#         "markdown": "# Shot 00:16.100 => 00:19.433\n## Transcript\n```\nWEBVTT\n\n00:13.440 --> 00:23.640\n<v Speaker>We actually accumulated tons of the data so that this universal model is able to capture the nuance of the audio and generate a more natural voice for the algorithm.\n```\n## Key Frames\n- 00:16.929 ![](keyFrame.16929.jpg)\n- 00:17.754 ![](keyFrame.17754.jpg)\n- 00:18.579 ![](keyFrame.18579.jpg)",
#         "fields": {},
#         "kind": "audioVisual",
#         "startTimeMs": 16100,
#         "endTimeMs": 19433,
#         "width": 1080,
#         "height": 608,
#         "KeyFrameTimesMs": [
#           16929,
#           17754,
#           18579
#         ],
#         "transcriptPhrases": [
#           {
#             "speaker": "speaker",
#             "startTimeMs": 13440,
#             "endTimeMs": 23640,
#             "text": "We actually accumulated tons of the data so that this universal model is able to capture the nuance of the audio and generate a more natural voice for the algorithm.",
#             "confidence": 1,
#             "words": [],
#             "locale": "en-US"
#           }
#         ]
#       },
#       {
#         "markdown": "# Shot 00:19.433 => 00:23.967\n## Transcript\n```\nWEBVTT\n\n00:13.440 --> 00:23.640\n<v Speaker>We actually accumulated tons of the data so that this universal model is able to capture the nuance of the audio and generate a more natural voice for the algorithm.\n```\n## Key Frames\n- 00:20.196 ![](keyFrame.20196.jpg)\n- 00:20.955 ![](keyFrame.20955.jpg)\n- 00:21.714 ![](keyFrame.21714.jpg)\n- 00:22.473 ![](keyFrame.22473.jpg)\n- 00:23.232 ![](keyFrame.23232.jpg)",
#         "fields": {},
#         "kind": "audioVisual",
#         "startTimeMs": 19433,
#         "endTimeMs": 23967,
#         "width": 1080,
#         "height": 608,
#         "KeyFrameTimesMs": [
#           20196,
#           20955,
#           21714,
#           22473,
#           23232
#         ],
#         "transcriptPhrases": [
#           {
#             "speaker": "speaker",
#             "startTimeMs": 13440,
#             "endTimeMs": 23640,
#             "text": "We actually accumulated tons of the data so that this universal model is able to capture the nuance of the audio and generate a more natural voice for the algorithm.",
#             "confidence": 1,
#             "words": [],
#             "locale": "en-US"
#           }
#         ]
#       },
#       {
#         "markdown": "# Shot 00:23.967 => 00:30.033\n## Transcript\n```\nWEBVTT\n\n00:24.080 --> 00:29.120\n<v Speaker>What we liked about cognitive services offerings were that they had a much higher fidelity.\n00:29.600 --> 00:32.880\n<v Speaker>And they sounded a lot more like an actual human voice.\n```\n## Key Frames\n- 00:24.816 ![](keyFrame.24816.jpg)\n- 00:25.674 ![](keyFrame.25674.jpg)\n- 00:26.532 ![](keyFrame.26532.jpg)\n- 00:27.390 ![](keyFrame.27390.jpg)\n- 00:28.248 ![](keyFrame.28248.jpg)\n- 00:29.106 ![](keyFrame.29106.jpg)",
#         "fields": {},
#         "kind": "audioVisual",
#         "startTimeMs": 23967,
#         "endTimeMs": 30033,
#         "width": 1080,
#         "height": 608,
#         "KeyFrameTimesMs": [
#           24816,
#           25674,
#           26532,
#           27390,
#           28248,
#           29106
#         ],
#         "transcriptPhrases": [
#           {
#             "speaker": "speaker",
#             "startTimeMs": 24080,
#             "endTimeMs": 29120,
#             "text": "What we liked about cognitive services offerings were that they had a much higher fidelity.",
#             "confidence": 1,
#             "words": [],
#             "locale": "en-US"
#           },
#           {
#             "speaker": "speaker",
#             "startTimeMs": 29600,
#             "endTimeMs": 32880,
#             "text": "And they sounded a lot more like an actual human voice.",
#             "confidence": 1,
#             "words": [],
#             "locale": "en-US"
#           }
#         ]
#       },
#       {
#         "markdown": "# Shot 00:30.033 => 00:33.200\n## Transcript\n```\nWEBVTT\n\n00:29.600 --> 00:32.880\n<v Speaker>And they sounded a lot more like an actual human voice.\n```\n## Key Frames\n- 00:30.822 ![](keyFrame.30822.jpg)\n- 00:31.614 ![](keyFrame.31614.jpg)\n- 00:32.406 ![](keyFrame.32406.jpg)",
#         "fields": {},
#         "kind": "audioVisual",
#         "startTimeMs": 30033,
#         "endTimeMs": 33200,
#         "width": 1080,
#         "height": 608,
#         "KeyFrameTimesMs": [
#           30822,
#           31614,
#           32406
#         ],
#         "transcriptPhrases": [
#           {
#             "speaker": "speaker",
#             "startTimeMs": 29600,
#             "endTimeMs": 32880,
#             "text": "And they sounded a lot more like an actual human voice.",
#             "confidence": 1,
#             "words": [],
#             "locale": "en-US"
#           }
#         ]
#       },
#       {
#         "markdown": "# Shot 00:33.200 => 00:35.267\n## Transcript\n```\nWEBVTT\n\n00:33.720 --> 00:37.080\n<v Speaker>Orlando ground 9555 requesting the end of pushback.\n```\n## Key Frames\n- 00:33.891 ![](keyFrame.33891.jpg)\n- 00:34.584 ![](keyFrame.34584.jpg)",
#         "fields": {},
#         "kind": "audioVisual",
#         "startTimeMs": 33200,
#         "endTimeMs": 35267,
#         "width": 1080,
#         "height": 608,
#         "KeyFrameTimesMs": [
#           33891,
#           34584
#         ],
#         "transcriptPhrases": [
#           {
#             "speaker": "speaker",
#             "startTimeMs": 33720,
#             "endTimeMs": 37080,
#             "text": "Orlando ground 9555 requesting the end of pushback.",
#             "confidence": 1,
#             "words": [],
#             "locale": "en-US"
#           }
#         ]
#       },
#       {
#         "markdown": "# Shot 00:35.267 => 00:37.700\n## Transcript\n```\nWEBVTT\n\n00:33.720 --> 00:37.080\n<v Speaker>Orlando ground 9555 requesting the end of pushback.\n```\n## Key Frames\n- 00:36.069 ![](keyFrame.36069.jpg)\n- 00:36.861 ![](keyFrame.36861.jpg)",
#         "fields": {},
#         "kind": "audioVisual",
#         "startTimeMs": 35267,
#         "endTimeMs": 37700,
#         "width": 1080,
#         "height": 608,
#         "KeyFrameTimesMs": [
#           36069,
#           36861
#         ],
#         "transcriptPhrases": [
#           {
#             "speaker": "speaker",
#             "startTimeMs": 33720,
#             "endTimeMs": 37080,
#             "text": "Orlando ground 9555 requesting the end of pushback.",
#             "confidence": 1,
#             "words": [],
#             "locale": "en-US"
#           }
#         ]
#       },
#       {
#         "markdown": "# Shot 00:37.700 => 00:39.200\n## Transcript\n```\nWEBVTT\n\n00:38.800 --> 00:41.160\n<v Speaker>9555 request to end pushback received.\n```\n## Key Frames\n- 00:38.181 ![](keyFrame.38181.jpg)\n- 00:38.676 ![](keyFrame.38676.jpg)",
#         "fields": {},
#         "kind": "audioVisual",
#         "startTimeMs": 37700,
#         "endTimeMs": 39200,
#         "width": 1080,
#         "height": 608,
#         "KeyFrameTimesMs": [
#           38181,
#           38676
#         ],
#         "transcriptPhrases": [
#           {
#             "speaker": "speaker",
#             "startTimeMs": 38800,
#             "endTimeMs": 41160,
#             "text": "9555 request to end pushback received.",
#             "confidence": 1,
#             "words": [],
#             "locale": "en-US"
#           }
#         ]
#       },
#       {
#         "markdown": "# Shot 00:39.200 => 00:42.033\n## Transcript\n```\nWEBVTT\n\n00:38.800 --> 00:41.160\n<v Speaker>9555 request to end pushback received.\n```\n## Key Frames\n- 00:39.897 ![](keyFrame.39897.jpg)\n- 00:40.590 ![](keyFrame.40590.jpg)\n- 00:41.283 ![](keyFrame.41283.jpg)",
#         "fields": {},
#         "kind": "audioVisual",
#         "startTimeMs": 39200,
#         "endTimeMs": 42033,
#         "width": 1080,
#         "height": 608,
#         "KeyFrameTimesMs": [
#           39897,
#           40590,
#           41283
#         ],
#         "transcriptPhrases": [
#           {
#             "speaker": "speaker",
#             "startTimeMs": 38800,
#             "endTimeMs": 41160,
#             "text": "9555 request to end pushback received.",
#             "confidence": 1,
#             "words": [],
#             "locale": "en-US"
#           }
#         ]
#       },
#       {
#         "markdown": "# Shot 00:42.033 => 00:43.866\n## Transcript\n```\nWEBVTT\n\n```\n## Key Frames\n- 00:42.636 ![](keyFrame.42636.jpg)\n- 00:43.230 ![](keyFrame.43230.jpg)",
#         "fields": {},
#         "kind": "audioVisual",
#         "startTimeMs": 42033,
#         "endTimeMs": 43866,
#         "width": 1080,
#         "height": 608,
#         "KeyFrameTimesMs": [
#           42636,
#           43230
#         ],
#         "transcriptPhrases": []
#       }
#     ]
#   }
# }
# Unique Keyframe IDs: {'keyFrame.14190', 'keyFrame.726', 'keyFrame.24816', 'keyFrame.38181', 'keyFrame.20955', 'keyFrame.15444', 'keyFrame.32406', 'keyFrame.5709', 'keyFrame.27390', 'keyFrame.21714', 'keyFrame.22473', 'keyFrame.43230', 'keyFrame.2640', 'keyFrame.2046', 'keyFrame.36069', 'keyFrame.4059', 'keyFrame.42636', 'keyFrame.29106', 'keyFrame.38676', 'keyFrame.33891', 'keyFrame.39897', 'keyFrame.40590', 'keyFrame.8976', 'keyFrame.31614', 'keyFrame.7788', 'keyFrame.28248', 'keyFrame.4884', 'keyFrame.17754', 'keyFrame.41283', 'keyFrame.14817', 'keyFrame.12078', 'keyFrame.30822', 'keyFrame.23232', 'keyFrame.36861', 'keyFrame.26532', 'keyFrame.34584', 'keyFrame.10560', 'keyFrame.6534', 'keyFrame.18579', 'keyFrame.20196', 'keyFrame.9768', 'keyFrame.16929', 'keyFrame.12804', 'keyFrame.25674'}
# INFO:python.content_understanding_client:Analyzer content-video-sample-cd025723-239e-42a1-a940-04c5cf0b4bc4 deleted.
# <Response [204]>

# %% [markdown]
# ## Video Content with Face
# This is a gated feature, please go through process [Azure AI Resource Face Gating](https://learn.microsoft.com/en-us/legal/cognitive-services/computer-vision/limited-access-identity?context=%2Fazure%2Fai-services%2Fcomputer-vision%2Fcontext%2Fcontext#registration-process) Select `[Video Indexer] Facial Identification (1:N or 1:1 matching) to search for a face in a media or entertainment video archive to find a face within a video and generate metadata for media or entertainment use cases only` in the registration form.

# %%
ANALYZER_ID = "content-video-face-sample-" + str(uuid.uuid4())
ANALYZER_TEMPLATE_FILE = '../analyzer_templates/face_aware_in_video.json'
ANALYZER_SAMPLE_FILE = '../data/FlightSimulator.mp4'

# Create analyzer
response = client.begin_create_analyzer(ANALYZER_ID, analyzer_template_path=ANALYZER_TEMPLATE_FILE)
result = client.poll_result(response)

# Analyzer file
response = client.begin_analyze(ANALYZER_ID, file_location=ANALYZER_SAMPLE_FILE)
result = client.poll_result(response)

print(json.dumps(result, indent=2))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[14], line 6
#       3 ANALYZER_SAMPLE_FILE = '../data/FlightSimulator.mp4'
#       5 # Create analyzer
# ----> 6 response = client.begin_create_analyzer(ANALYZER_ID, analyzer_template_path=ANALYZER_TEMPLATE_FILE)
#       7 result = client.poll_result(response)
#       9 # Analyzer file
#
# File c:\Users\jomedin\Documents\Azure_AI_Services\azure-ai-content-understanding-python-main\python\content_understanding_client.py:160, in AzureContentUnderstandingClient.begin_create_analyzer(self, analyzer_id, analyzer_template, analyzer_template_path, training_storage_container_sas_url, training_storage_container_path_prefix)
#     153 headers.update(self._headers)
#     155 response = requests.put(
#     156     url=self._get_analyzer_url(self._endpoint, self._api_version, analyzer_id),
#     157     headers=headers,
#     158     json=analyzer_template,
#     159 )
# --> 160 response.raise_for_status()
#     161 self._logger.info(f"Analyzer {analyzer_id} create request accepted.")
#     162 return response
#
# File c:\Users\jomedin\AppData\Local\anaconda3\envs\secdemo\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://demotestcu.services.ai.azure.com/contentunderstanding/analyzers/content-video-face-sample-9b1b75a0-6ab0-4d31-bb3f-9eec4688f95d?api-version=2024-12-01-preview

# %% [markdown]
# ### Get and Save Key Frames and Face Thumbnails

# %%
# Initialize sets for unique face IDs and keyframe IDs
face_ids = set()
keyframe_ids = set()

# Extract unique face IDs safely
result_data = result.get("result", {})
contents = result_data.get("contents", [])

# Iterate over contents to find faces and keyframes if available
for content in contents:
    # Safely retrieve face IDs if "faces" exists and is a list
    faces = content.get("faces", [])
    if isinstance(faces, list):
        for face in faces:
            face_id = face.get("faceId")
            if face_id:
                face_ids.add(f"face.{face_id}")

    # Extract keyframe IDs from "markdown" if it exists and is a string
    markdown_content = content.get("markdown", "")
    if isinstance(markdown_content, str):
        keyframe_ids.update(re.findall(r"(keyFrame\.\d+)\.jpg", markdown_content))

# Output the results
print("Unique Face IDs:", face_ids)
print("Unique Keyframe IDs:", keyframe_ids)

# Save all face images
for face_id in face_ids:
    save_image(face_id, response)

# Save all keyframe images
for keyframe_id in keyframe_ids:
    save_image(keyframe_id, response)

# %% [markdown]
# ## Clean Up
# Optionally, delete the sample analyzer from your resource. In typical usage scenarios, you would analyze multiple files using the same analyzer.

# %%
client.delete_analyzer(ANALYZER_ID)
# Out:
# INFO:python.content_understanding_client:Analyzer content-video-face-sample-12d4197c-c511-42e1-80d0-7f396ea6d84c deleted.
# <Response [204]>
